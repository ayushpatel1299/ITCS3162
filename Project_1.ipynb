# %%
# !pip install numpy pandas matplotlib seaborn

# %%
import numpy as np

# %%
import pandas as pd

# %%
veteran_df = pd.read_csv("2011.csv")

# %%
veteran_df.head()
# Out:
#    Unnamed: 0       state  vet_pop  overall_pop_18  vet_pop_p  vet_suicides  \
# 0           0     Alabama   395753         3662910   0.108043           163
# 1           1      Alaska    72407          517799   0.139836            27
# 2           2     Arizona   533608         4842927   0.110183           242
# 3           3    Arkansas   238790         2221409   0.107495            89
# 4           4  California  1910994        28292703   0.067544           706
#
#    all_suicides  vet_suicides_p  vet_males  vet_males_p  ...  vet_40_49  \
# 0           680        0.239706        NaN     0.000000  ...        NaN
# 1           142        0.190141       24.0     0.888889  ...        NaN
# 2          1091        0.221815        NaN     0.000000  ...        NaN
# 3           447        0.199105       89.0     1.000000  ...        NaN
# 4          3923        0.179964      679.0     0.961756  ...        NaN
#
#    vet_35-54  vet_45_54  vet_50_59  vet_45_64  vet_55_64  vet_60  vet_65  \
# ...

# %%
veteran_df.describe()
# Out:
#        Unnamed: 0       vet_pop  overall_pop_18  vet_pop_p  vet_suicides  \
# count    50.00000  5.000000e+01    5.000000e+01  50.000000     50.000000
# mean     24.50000  4.285742e+05    4.723110e+06   0.100060    146.920000
# std      14.57738  4.056443e+05    5.228324e+06   0.015842    144.131437
# min       0.00000  5.137300e+04    4.305540e+05   0.060533     17.000000
# 25%      12.25000  1.462795e+05    1.400043e+06   0.091527     56.000000
# 50%      24.50000  3.194590e+05    3.386286e+06   0.103733    109.000000
# 75%      36.75000  5.227465e+05    5.190174e+06   0.110908    190.750000
# max      49.00000  1.910994e+06    2.829270e+07   0.139836    706.000000
#
#        all_suicides  vet_suicides_p   vet_males  vet_males_p  vet_females  \
# count      50.00000       50.000000   31.000000    50.000000    32.000000
# mean      764.86000        0.191230  151.064516     0.598244     4.937500
# std       745.08408        0.034064  141.571404     0.473587     6.137865
# ...

# %%
veteran_df[['state', 'overall_pop_18', 'vet_pop', 'all_suicides', 'vet_suicides', 'vet_suicides_p']]
# Out:
#              state  overall_pop_18  vet_pop  all_suicides  vet_suicides  \
# 0          Alabama         3662910   395753           680           163
# 1           Alaska          517799    72407           142            27
# 2          Arizona         4842927   533608          1091           242
# 3         Arkansas         2221409   238790           447            89
# 4       California        28292703  1910994          3923           706
# 5         Colorado         3857537   411754           879           170
# 6      Connecticut         2768440   225987           364            54
# 7         Delaware          699180    77885           116            17
# 8         Florida*        15012091  1571482          2789           642
# 9          Georgia         7279776   686591          1133           218
# 10          Hawaii         1034113   109218           207            27
# 11           Idaho         1155068   121382           290            68
# ...

# %%
veteran_df['vet_suicides_p'].apply(lambda p: p * 100)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
veteran_df.plot(x='state', y='vet_suicides_p', kind='bar')
# Out:
# <Axes: xlabel='state'>

# %%
sns.pairplot(data=veteran_df)

# %%
veteran_df[['vet_rate', 'civ_rate']]
# Out:
#      vet_rate   civ_rate
# 0   41.187306  15.824155
# 1   37.289212  25.819952
# 2   45.351644  19.701489
# 3   37.271243  18.056924
# 4   36.944124  12.194055
# 5   41.286788  20.575875
# 6   23.895180  12.192949
# 7   21.827053  15.934459
# 8   40.853156  15.973979
# 9   31.751072  13.877966
# 10  24.721200  19.461669
# 11  56.021486  21.476541
# 12  26.545180  10.982203
# 13  35.734285  15.639097
# 14  36.606288  13.600903
# 15  34.246575  17.060621
# 16  39.862026  17.123515
# 17  33.870901  14.635838
# 18  23.266636  18.116919
# 19  21.128596  10.268155
# 20  15.260897  11.230071
# 21  32.337334  15.301018
# 22  30.535184  13.870173
# 23  37.783125  15.194723
# 24  36.722553  16.950363
# 25  57.972848  24.955700
# 26  23.271095  12.263521
# 27  53.458830  23.716626
# 28  28.621733  18.437878
# 29  20.679408   9.104090
# 30  46.881796  24.671846
# 31  26.587022   9.218440
# 32  27.955218  14.729471
# 33  44.999640  16.727861
# 34  30.816184  12.602417
# 35  44.100537  19.696812
# ...

# %%
veteran_df.plot(x='state', y='vet_rate', kind='bar')
